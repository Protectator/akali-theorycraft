# %% [markdown]
# # League of Legends : Akali
#
# ## Theorycraft about Akali's damage in the the 6.22 patch
#
# This document presents graphs showing the differences between old and new Akali's spells.
#
# The complete and official patch note is avalable [here](http://na.leagueoflegends.com/en/news/game-updates/patch/patch-622-notes).
#
# If you want interactive graphs for changing Akali's and the enemy target's stats, download the notebook [here](https://github.com/Protectator/akali-theorycraft) and run it on your machine using a [Jupyter Notebook](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest).
#
# Document by [Protectator](https://twitter.com/Protectator).

# %%
from akali_622_code import *
# %matplotlib inline

# %% [markdown]
# *Hint* : In the following graphs, each line of a color represents a level of Akali. Darker ones = Higher levels.

# %% [markdown]
# ---
# <img src="p.png">
# ### P - Twin Disciplines
#
# Updated : Akali’s first two attacks have bonus effects. Akali’s first basic attack heals her, while the second deals bonus damage. A few seconds after her first attack, this resets.
#
# * Cooldown : 8/7/6/5/4 after first attack (at levels 1/3/5/7/9)
# * First Strike Healing : 5-60 (at levels 1-18)
# * Healing Ratio : 0.6 bonus attack damage + 0.3 ability power
# * Second Strike Damage : 10-100 (at levels 1-18)
# * Second Strike Ratio : 0.5 bonus attack damage + 0.5 ability power
#
# *Note* : The graph here shows only the bonus damages of the second hit.

# %%
show_p() # Graph and sliders of the Passive

# %% [markdown]
# ---
# <img src="q.png">
# ### Q - Mark of the Assassin
#
# Q is unchanged

# %%
show_q() # Graph and sliders of Mark of the Assassin

# %% [markdown]
# ---
# <img src="e.png">
# ### E - Crescent Slash
#
# * Cooldown : 5/4/3/2/1 second ⇒ 5/4.5/4/3.5/3 seconds
# * Damage : 30/55/80/105/130 ⇒ 70/100/130/160/190
# * Ratio : 0.4 ability power + 0.6 total attack damage ⇒ 0.5 ability power + 0.7 bonus attack damage
# * Reset : If Crescent Slash kills a unit, its cooldown is 60% refunded

# %%
show_e() # Graph and sliders of Crescent Slash

# %% [markdown]
# ---
# <img src="r.png">
# ### R - Shadow Dance
#
# * Cooldown : 2/1.5/1 second ⇒ 2 seconds
# * Damage : 100/175/250 ⇒ 50/100/150
# * Ratio : 0.5 ability power ⇒ 0.25 ability power

# %%
show_r() # Graph and sliders of Shadow Dance
